# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report

from sklearn.model_selection import GridSearchCV

# %%
df = load_breast_cancer(as_frame = True).frame

# %%
df.sample()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 437        14.04         15.98           89.78      611.2          0.08458
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 437           0.05895         0.03534              0.02944         0.1714
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 437                 0.05898  ...          21.58            101.2       750.0
#
#      worst smoothness  worst compactness  worst concavity  \
# 437            0.1195             0.1252           0.1117
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 437               0.07453          0.2725                  0.07234       1
#
# [1 rows x 31 columns]

# %%
df.shape
# Out:
# (569, 31)

# %%
x = df.drop(['target'], axis = 1)
y = df['target']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
grid = {
    'criterion':['gini', 'entropy'],
    'max_depth': [3,4,5,6,7,8,9,10, None]
}

# %%
grid_cv = GridSearchCV(
    estimator = DecisionTreeClassifier(),
    param_grid = grid,
    cv = 5
)
grid_cv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 6, 7, 8, 9, 10, None]})

# %%
y_pred1 = grid_cv.predict(x_train)
print(accuracy_score(y_train, y_pred1))

y_pred = grid_cv.predict(x_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9912087912087912
# 0.956140350877193

# %%
grid_param = {
    'n_estimators': [100,150,200,300,400],
    'criterion':['gini','entropy'],
    'max_features':['sqrt','log2']
}

# %%
grid_cv_RF = GridSearchCV(
    estimator = RandomForestClassifier(),
    param_grid = grid_param,
    cv = 5
)
grid_cv_RF.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [100, 150, 200, 300, 400]})

# %%
y_pred1 = grid_cv_RF.predict(x_train)
print(accuracy_score(y_train, y_pred1))

y_pred = grid_cv_RF.predict(x_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 1.0
# 0.9649122807017544

# %% [markdown]
# here We can See Random Forest perfoming better because it uses multiple decision trees in each model and brings out the better accuracy than decision tree
